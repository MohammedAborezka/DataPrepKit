# %%
pip install DataPrepKit_mv

# %%
from DataPrepKit_mv.DataPrepKit_mv import read_data

# %%
df = read_data()
# Out:
# please enter file path
# sorry try again with valid file name format json,excel or csv

# %% [markdown]
# # Data Understanding

# %%
df.show()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group B           bachelor's degree      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72           72.0           74.0
# 1                    none          72           72.0           74.0
# 2                    none          90            NaN           93.0
# 3                    none          47           57.0            NaN
# 4                    none          76           78.0            NaN

# %%
df.summary()
# Out:
# rows: 1000 columns: 8
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       997 non-null    object
#  1   race/ethnicity               999 non-null    object
#  2   parental level of education  999 non-null    object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                999 non-null    float64
#  7   writing score                997 non-null    float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 62.6+ KB
# None
#         math score  reading score  writing score
# count  1000.000000     999.000000     997.000000
# mean     66.092000      69.125125      68.047141
# ...

# %%
df.col_names()
# Out:
# index name
#   0  gender
#   1  race/ethnicity
#   2  parental level of education
#   3  lunch
#   4  test preparation course
#   5  math score
#   6  reading score
#   7  writing score

# %%
df.rename_col("gender","Gender")

# %%
df.col_names()
# Out:
# index name
#   0  Gender
#   1  race/ethnicity
#   2  parental level of education
#   3  lunch
#   4  test preparation course
#   5  math score
#   6  reading score
#   7  writing score

# %%
df.unique_values()
# Out:
# ColumnName ----------------UniqueValues
# Gender --> ['female' 'male' nan]
# ...
# ColumnName ----------------UniqueValues
# race/ethnicity --> ['group B' 'group A' 'group C' 'group D' 'group E' nan]
# ...
# ColumnName ----------------UniqueValues
# parental level of education --> ["bachelor's degree" "master's degree" "associate's degree" 'some college'
#  'high school' 'some high school' nan]
# ...
# ColumnName ----------------UniqueValues
# lunch --> ['standard' 'free/reduced']
# ...
# ColumnName ----------------UniqueValues
# test preparation course --> ['none' 'completed']
# ...
# ColumnName ----------------UniqueValues
# math score --> [ 72  90  47  76  71  88  40  64  38  58  65  78  50  69  18  46  54  66
#   44  74  73  67  70  62  63  56  97  81  75  57  55  53  59  82  77  33
#   52   0  79  39  45  60  61  41  49  30  80  42  27  43  68  85  98  87
#   51  99  84  91  83  89  22 100  96  94  48  35  34  86  92  37  28  24
#   26  95  36  29  32  93  19  23   8]
# ...

# %%
df.null_sum()
# Out:
# ColumnName-------------HowManyNulls
# Gender                         3
# race/ethnicity                 1
# parental level of education    1
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  1
# writing score                  3
# dtype: int64

# %%
df.show_row_wnull("Gender")
# Out:
#     Gender race/ethnicity parental level of education         lunch  \
# 994    NaN        group A                 high school      standard
# 995    NaN        group E             master's degree      standard
# 997    NaN            NaN                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 994                    none          63           63.0           62.0
# 995               completed          88           99.0           95.0
# 997               completed          59           71.0           65.0

# %%
df.dis_duplic_row()
# Out:
#    Gender race/ethnicity parental level of education     lunch  \
# 1  female        group B           bachelor's degree  standard
#
#   test preparation course  math score  reading score  writing score
# 1                    none          72           72.0           74.0
# Do you want to drop duplicts? y/nn

# %%
df.dublic_basedOn_col("Gender","race/ethnicity","parental level of education","lunch","test preparation course")
# Out:
#      Gender race/ethnicity parental level of education         lunch  \
# 1    female        group B           bachelor's degree      standard
# 23   female        group C            some high school      standard
# 28     male        group C                 high school      standard
# 33     male        group D                some college      standard
# 42   female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 996    male        group C                 high school  free/reduced
# 998  female        group D                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # Data Prepartion

# %%
df.drop_col_wname("race/ethnicity")

# %%
df.show()
# Out:
#    Gender parental level of education         lunch test preparation course  \
# 0  female           bachelor's degree      standard                    none
# 1  female           bachelor's degree      standard                    none
# 2  female             master's degree      standard                    none
# 3    male          associate's degree  free/reduced                    none
# 4    male                some college      standard                    none
#
#    math score  reading score  writing score
# 0          72           72.0           74.0
# 1          72           72.0           74.0
# 2          90            NaN           93.0
# 3          47           57.0            NaN
# 4          76           78.0            NaN

# %%
df.drop_bcol_value("Gender","male")

# %%
df.show(10)
# Out:
#    Gender parental level of education         lunch test preparation course  \
# 0  female           bachelor's degree      standard                    none
# 1  female           bachelor's degree      standard                    none
# 2  female             master's degree      standard                    none
# 3    male          associate's degree  free/reduced                    none
# 4    male                some college      standard                    none
# 5  female          associate's degree      standard                    none
# 6  female                some college      standard               completed
# 7    male                some college  free/reduced                    none
# 8    male                 high school  free/reduced               completed
# 9  female                 high school  free/reduced                    none
#
#    math score  reading score  writing score
# 0          72           72.0           74.0
# ...

# %%
df.fill_missing_numbers("ch")
# Out:
# this columns ['reading score', 'writing score'] contain nulls
# how you would like to fill reading score with  median , mode , mean or a number mode
# how you would like to fill writing score with  median , mode , mean or a number median

# %%
#df.fill_missing_catg("n")

# %%
df.fill_missing_catg()
# Out:
# No missing values in categorical columns

# %%
df.catg_ecoding_col("gender")
# Out:
#   race/ethnicity parental level of education         lunch  \
# 0        group B           bachelor's degree      standard
# 1        group B           bachelor's degree      standard
# 2        group B             master's degree      standard
# 3        group A          associate's degree  free/reduced
# 4        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72           72.0           74.0
# 1                    none          72           72.0           74.0
# 2                    none          90           72.0           93.0
# 3                    none          47           57.0           69.0
# 4                    none          76           78.0           69.0
#
#    gender_female  gender_male
# 0              1            0
# 1              1            0
# 2              1            0
# 3              0            1
# 4              0            1

# %%
#you can chose one of those to handel missing values in certain column
"""
df.fill_col_wmean()
df.fill_col_wmedian()
df.fill_col_wmode()
"""
# Out:
# '\ndf.fill_col_wmean()\ndf.fill_col_wmedian()\ndf.fill_col_wmode()\n'

# %%
df.plot_two_col("math score","writing score")
